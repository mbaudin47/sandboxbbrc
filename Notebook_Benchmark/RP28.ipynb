# %% [markdown]
# # Problème RP28

# %%
import openturns as ot
import numpy as np

# %% [markdown]
# ## Variables d'entrée

# %%
X1 = ot.Normal(78064 , 11710)
X2 = ot.Normal(0.0104 , 0.00156)

# %%
myDistribution=ot.ComposedDistribution([X1, X2])

# %% [markdown]
# ## Fonction de performance

# %%
myFunction = ot.SymbolicFunction(["x1", "x2"], ["  x1 * x2 - 146.14 "])

# %%
vect = ot.RandomVector(myDistribution)
output = ot.CompositeRandomVector(myFunction, vect)
event = ot.ThresholdEvent(output, ot.Less(), 0)

# %%
mu = myDistribution.getMean()

# %% [markdown]
# ## Calcul de la probabilité de défaillance par la méthode de FORM

# %%
solver = ot.AbdoRackwitz()
algo = ot.FORM(solver, event,mu)
algo.run()
result = algo.getResult()

# %%
result.getEventProbability()
# Out:
# 2.850405832410586e-08

# %% [markdown]
# ## Calcul de la probabilité de défaillance par la méthode de SORM

# %%
solver = ot.AbdoRackwitz()
algo = ot.SORM(solver, event,mu)
algo.run()
result = algo.getResult()

# %%
#result.getEventProbabilityBreitung()

# %% [markdown]
# ## Calcul de la probabilité de défaillance par la méthode du Tirage d'importance

# %%
standardSpaceDesignPoint = result.getStandardSpaceDesignPoint()
myImportance = ot.Normal(standardSpaceDesignPoint, [1.0] * 2, ot.CorrelationMatrix(2))
experiment = ot.ImportanceSamplingExperiment(myImportance)
algo = ot.ProbabilitySimulationAlgorithm(ot.StandardEvent(event), experiment)
algo.setMaximumCoefficientOfVariation(0.1)
algo.setMaximumOuterSampling(40000)
algo.setConvergenceStrategy(ot.Full())
algo.run()

# %%
result = algo.getResult()
result.getProbabilityEstimate()
# Out:
# 1.4086354889144684e-07

# %% [markdown]
# ## Calcul de la probabilité de défaillance par la méthode de Monte Carlo

# %%
algoProb = ot.ProbabilitySimulationAlgorithm(event)
algoProb.setMaximumOuterSampling(1000)
algoProb.setMaximumCoefficientOfVariation(0.01)
algoProb.run()

# %%
resultAlgo = algoProb.getResult()
pf = resultAlgo.getProbabilityEstimate()
pf
# Out:
# 0.0

# %% [markdown]
# ## Les courbes iso-probables

# %%
alphaMin = 0.01
alphaMax = 1 - alphaMin
lowerBound = ot.Point([X1.computeQuantile(alphaMin)[0], X2.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X1.computeQuantile(alphaMax)[0], X2.computeQuantile(alphaMax)[0]])

# %%
nbPoints = [100, 100]
figure = myFunction.draw(lowerBound, upperBound, nbPoints)
figure.setTitle(" Les courbes iso-probables")
figure
# Out:
# class=Graph name=y0 as a function of (x1,x2) implementation=class=GraphImplementation name=y0 as a function of (x1,x2) title= Les courbes iso-probables xTitle=x1 yTitle=x2 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=y0 as a function of (x1,x2) implementation=class=Contour name=y0 as a function of (x1,x2) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[50822.5],[51372.8],[51923.1],[52473.5],[53023.8],[53574.1],[54124.5],[54674.8],[55225.1],[55775.5],[56325.8],[56876.1],[57426.5],[57976.8],[58527.1],[59077.5],[59627.8],[60178.1],[60728.5],[61278.8],[61829.1],[62379.5],[62929.8],[63480.1],[64030.5],[64580.8],[65131.2],[65681.5],[66231.8],[66782.2],[67332.5],[67882.8],[68433.2],[68983.5],[69533.8],[70084.2],[70634.5],[71184.8],[71735.2],[72285.5],[72835.8],[73386.2],[73936.5],[74486.8],[75037.2],[75587.5],[76137.8],[76688.2],[77238.5],[77788.8],[78339.2],[78889.5],[79439.8],[79990.2],[80540.5],[81090.8],[81641.2],[82191.5],[82741.8],[83292.2],[83842.5],[84392.8],[84943.2],[85493.5],[86043.8],[86594.2],[87144.5],[87694.8],[88245.2],[88795.5],[89345.8],[89896.2],[90446.5],[90996.8],[91547.2],[92097.5],[92647.9],[93198.2],[93748.5],[94298.9],[94849.2],[95399.5],[95949.9],[96500.2],[97050.5],[97600.9],[98151.2],[98701.5],[99251.9],[99802.2],[100353],[100903],[101453],[102004],[102554],[103104],[103655],[104205],[104755],[105306]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[0.0067709],[0.00684421],[0.00691753],[0.00699084],[0.00706416],[0.00713747],[0.00721079],[0.0072841],[0.00735742],[0.00743073],[0.00750405],[0.00757736],[0.00765068],[0.00772399],[0.00779731],[0.00787063],[0.00794394],[0.00801726],[0.00809057],[0.00816389],[0.0082372],[0.00831052],[0.00838383],[0.00845715],[0.00853046],[0.00860378],[0.00867709],[0.00875041],[0.00882372],[0.00889704],[0.00897035],[0.00904367],[0.00911698],[0.0091903],[0.00926361],[0.00933693],[0.00941024],[0.00948356],[0.00955688],[0.00963019],[0.00970351],[0.00977682],[0.00985014],[0.00992345],[0.00999677],[0.0100701],[0.0101434],[0.0102167],[0.01029],[0.0103633],[0.0104367],[0.01051],[0.0105833],[0.0106566],[0.0107299],[0.0108032],[0.0108765],[0.0109499],[0.0110232],[0.0110965],[0.0111698],[0.0112431],[0.0113164],[0.0113898],[0.0114631],[0.0115364],[0.0116097],[0.011683],[0.0117563],[0.0118296],[0.011903],[0.0119763],[0.0120496],[0.0121229],[0.0121962],[0.0122695],[0.0123429],[0.0124162],[0.0124895],[0.0125628],[0.0126361],[0.0127094],[0.0127827],[0.0128561],[0.0129294],[0.0130027],[0.013076],[0.0131493],[0.0132226],[0.013296],[0.0133693],[0.0134426],[0.0135159],[0.0135892],[0.0136625],[0.0137358],[0.0138092],[0.0138825],[0.0139558],[0.0140291]] levels=class=Point name=Unnamed dimension=1 values=[318.192] labels=[318.192] show labels=false derived from class=DrawableImplementation name=y0 as a function of (x1,x2) legend=318.192 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10000 dimension=1 description=[y0] data=[[197.974],[201.7],[205.426],...,[1315.76],[1323.48],[1331.2]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=y0 as a function of (x1,x2) implementation=class=Contour name=y0 as a function of (x1,x2) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[50822.5],[51372.8],[51923.1],[52473.5],[53023.8],[53574.1],[54124.5],[54674.8],[55225.1],[55775.5],[56325.8],[56876.1],[57426.5],[57976.8],[58527.1],[59077.5],[59627.8],[60178.1],[60728.5],[61278.8],[61829.1],[62379.5],[62929.8],[63480.1],[64030.5],[64580.8],[65131.2],[65681.5],[66231.8],[66782.2],[67332.5],[67882.8],[68433.2],[68983.5],[69533.8],[70084.2],[70634.5],[71184.8],[71735.2],[72285.5],[72835.8],[73386.2],[73936.5],[74486.8],[75037.2],[75587.5],[76137.8],[76688.2],[77238.5],[77788.8],[78339.2],[78889.5],[79439.8],[ ...

# %% [markdown]
# ## Afiichage Points défaillants / fiables

# %%
sampleSize = 10000
sampleInput = myDistribution.getSample(sampleSize)
Y = myFunction(sampleInput)
Yarray = np.array(Y)
indices = Yarray > 0.0
indices = indices.ravel()
Xarray = np.array(sampleInput)
XPositif = Xarray[indices, :]
autresIndices = [not indices[i] for i in range(len(indices))]
XNegatifs = Xarray[autresIndices, :]

# %%
myGraph = ot.Graph('Points défaillants / fiables', 'X1', 'X2', True, '')
myCloud = ot.Cloud(ot.Sample(XPositif), 'green', 'fsquare', '>0')
myGraph.add(myCloud)
myCloud = ot.Cloud(ot.Sample(XNegatifs), 'red', 'fsquare', '<0')
myGraph.add(myCloud)
myGraph.setLegendPosition("topright")
myGraph
# Out:
# class=Graph name=Points défaillants / fiables implementation=class=GraphImplementation name=Points défaillants / fiables title=Points défaillants / fiables xTitle=X1 yTitle=X2 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=>0 implementation=class=Cloud name=>0 derived from class=DrawableImplementation name=>0 legend=>0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10000 dimension=2 data=[[62667.6,0.00917597],[72637.6,0.0106863],[68956.8,0.00908062],...,[83996.9,0.0069619],[73596.8,0.0117649],[37750.5,0.00834432]] color=green fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1,class=Drawable name=<0 implementation=class=Cloud name=<0 derived from class=DrawableImplementation name=<0 legend=<0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=0 dimension=2 data=[] color=red fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1]

# %%
bounds = ot.Interval(lowerBound, upperBound)
bounds
# Out:
# class=Interval name=Unnamed dimension=2 lower bound=class=Point name=Unnamed dimension=2 values=[50822.5,0.0067709] upper bound=class=Point name=Unnamed dimension=2 values=[105306,0.0140291] finite lower bound=[1,1] finite upper bound=[1,1]

# %%
nX = 100
nY = 100
boxExperiment = ot.Box([nX, nY], bounds)
#grille régulier 
inputSample = boxExperiment.generate()
outputSample = myFunction(inputSample)

# %%
def linearSample(xmin, xmax, npoints):
    '''Returns a sample created from a regular grid
    from xmin to xmax with npoints points.'''
    step = (xmax-xmin)/(npoints-1)
    rg = ot.RegularGrid(xmin, step, npoints)
    vertices = rg.getVertices()
    return vertices

# %% [markdown]
# ## Surface d'état limite

# %%
# Create an empty graph
myGraph = ot.Graph('Limit state surface', 'X1', 'X2', True, '')
# Create the contour
levels = ot.Point([0.0])
labels = ["0.0"]
drawLabels = True
x = linearSample(lowerBound[0], upperBound[0], nX + 2)
y = linearSample(lowerBound[1], upperBound[1], nY + 2)
myContour = ot.Contour(x, y, outputSample, levels, labels, drawLabels)
myContour.setColor('black')
myGraph.add(myContour)

myGraph
# Out:
# class=Graph name=Limit state surface implementation=class=GraphImplementation name=Limit state surface title=Limit state surface xTitle=X1 yTitle=X2 axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Contour name=Unnamed x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[50822.5],[51361.9],[51901.3],[52440.8],[52980.2],[53519.6],[54059.1],[54598.5],[55138],[55677.4],[56216.8],[56756.3],[57295.7],[57835.1],[58374.6],[58914],[59453.4],[59992.9],[60532.3],[61071.8],[61611.2],[62150.6],[62690.1],[63229.5],[63768.9],[64308.4],[64847.8],[65387.2],[65926.7],[66466.1],[67005.6],[67545],[68084.4],[68623.9],[69163.3],[69702.7],[70242.2],[70781.6],[71321],[71860.5],[72399.9],[72939.4],[73478.8],[74018.2],[74557.7],[75097.1],[75636.5],[76176],[76715.4],[77254.8],[77794.3],[78333.7],[78873.2],[79412.6],[79952],[80491.5],[81030.9],[81570.3],[82109.8],[82649.2],[83188.6],[83728.1],[84267.5],[84807],[85346.4],[85885.8],[86425.3],[86964.7],[87504.1],[88043.6],[88583],[89122.4],[89661.9],[90201.3],[90740.8],[91280.2],[91819.6],[92359.1],[92898.5],[93437.9],[93977.4],[94516.8],[95056.2],[95595.7],[96135.1],[96674.6],[97214],[97753.4],[98292.9],[98832.3],[99371.7],[99911.2],[100451],[100990],[101529],[102069],[102608],[103148],[103687],[104227],[104766],[105306]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[0.0067709],[0.00684276],[0.00691462],[0.00698649],[0.00705835],[0.00713021],[0.00720208],[0.00727394],[0.0073458],[0.00741767],[0.00748953],[0.00756139],[0.00763326],[0.00770512],[0.00777699],[0.00784885],[0.00792071],[0.00799258],[0.00806444],[0.0081363],[0.00820817],[0.00828003],[0.00835189],[0.00842376],[0.00849562],[0.00856748],[0.00863935],[0.00871121],[0.00878307],[0.00885494],[0.0089268],[0.00899866],[0.00907053],[0.00914239],[0.00921425],[0.00928612],[0.00935798],[0.00942984],[0.00950171],[0.00957357],[0.00964543],[0.0097173],[0.00978916],[0.00986102],[0.00993289],[0.0100048],[0.0100766],[0.0101485],[0.0102203],[0.0102922],[0.0103641],[0.0104359],[0.0105078],[0.0105797],[0.0106515],[0.0107234],[0.0107952],[0.0108671],[0.010939],[0.0110108],[0.0110827],[0.0111546],[0.0112264],[0.0112983],[0.0113702],[0.011442],[0.0115139],[0.0115857],[0.0116576],[0.0117295],[0.0118013],[0.0118732],[0.0119451],[0.0120169],[0.0120888],[0.0121607],[0.0122325],[0.0123044],[0.0123762],[0.0124481],[0.01252],[0.0125918],[0.0126637],[0.0127356],[0.0128074],[0.0128793],[0.0129512],[0.013023],[0.0130949],[0.0131667],[0.0132386],[0.0133105],[0.0133823],[0.0134542],[0.0135261],[0.0135979],[0.0136698],[0.0137416],[0.0138135],[0.0138854],[0.0139572],[0.0140291]] levels=class=Point name=Unnamed dimension=1 values=[0] labels=[0.0] show labels=true derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=