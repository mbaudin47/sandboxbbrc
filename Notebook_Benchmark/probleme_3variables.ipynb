# %% [markdown]
# # Exemple à 3 variables

# %%
import openturns as ot
import numpy as np

# %% [markdown]
# On déclare les variables d'entrées

# %%
X1 = ot.Normal(0 , 1)
X2 = ot.Normal(0 , 1)
X3 = ot.Normal(0, 1)

# %%
myDistribution=ot.ComposedDistribution([X1, X2, X3])

# %% [markdown]
# La fonction $ g $ en format symbolique

# %%
f = ot.SymbolicFunction(['x1', 'x2' , 'x3'],[' x1*x1 -2 + x2*x3 - sin(x1*x3) '])

# %% [markdown]
# On définit les fonctions $ g_1 $ en fixant $ X_1 $ à son moyen. De la même façon, on définit $ g_2 $ et $ g_3 $.

# %%
g1 = ot.ParametricFunction(f, [0], [X1.getMean()[0]])
g2 = ot.ParametricFunction(f, [1], [X2.getMean()[0]])
g3 = ot.ParametricFunction(f, [2], [X3.getMean()[0]])

# %% [markdown]
# La fonction `ParametricFunction` permet de fixer les entrées qu'on veut fixer à certaines valeurs  et d'obtenir une nouvelle fonction

# %%
g3([1,1])
# Out:
# class=Point name=Unnamed dimension=1 values=[-1]

# %% [markdown]
# ## Les courbes iso-probables

# %%
alphaMin = 0.01
alphaMax = 1 - alphaMin
lowerBound = ot.Point([X1.computeQuantile(alphaMin)[0], X2.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X1.computeQuantile(alphaMax)[0], X2.computeQuantile(alphaMax)[0]])

# %%
nbPoints = [100, 100]
figure = g3.draw(lowerBound, upperBound, nbPoints)
figure.setTitle(" Les courbes iso-probables ")
figure
# Out:
# class=Graph name=y0 as a function of (x1,x2) implementation=class=GraphImplementation name=y0 as a function of (x1,x2) title= Les courbes iso-probables  xTitle=x1 yTitle=x2 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=y0 as a function of (x1,x2) implementation=class=Contour name=y0 as a function of (x1,x2) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985],[0.0704954],[0.117492],[0.164489],[0.211486],[0.258483],[0.30548],[0.352477],[0.399474],[0.446471],[0.493468],[0.540465],[0.587462],[0.634459],[0.681455],[0.728452],[0.775449],[0.822446],[0.869443],[0.91644],[0.963437],[1.01043],[1.05743],[1.10443],[1.15142],[1.19842],[1.24542],[1.29242],[1.33941],[1.38641],[1.43341],[1.4804],[1.5274],[1.5744],[1.62139],[1.66839],[1.71539],[1.76238],[1.80938],[1.85638],[1.90338],[1.95037],[1.99737],[2.04437],[2.09136],[2.13836],[2.18536],[2.23235],[2.27935],[2.32635]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985],[0.0704954],[0.117492],[0.164489],[0.211486],[0.258483],[0.30548],[0.352477],[0.399474],[0.446471],[0.493468],[0.540465],[0.587462],[0.634459],[0.681455],[0.728452],[0.775449],[0.822446],[0.869443],[0.91644],[0.963437],[1.01043],[1.05743],[1.10443],[1.15142],[1.19842],[1.24542],[1.29242],[1.33941],[1.38641],[1.43341],[1.4804],[1.5274],[1.5744],[1.62139],[1.66839],[1.71539],[1.76238],[1.80938],[1.85638],[1.90338],[1.95037],[1.99737],[2.04437],[2.09136],[2.13836],[2.18536],[2.23235],[2.27935],[2.32635]] levels=class=Point name=Unnamed dimension=1 values=[-1.9862] labels=[-1.9862] show labels=false derived from class=DrawableImplementation name=y0 as a function of (x1,x2) legend=-1.9862 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10000 dimension=1 description=[y0] data=[[3.41189],[3.19544],[2.9834],...,[2.9834],[3.19544],[3.41189]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=y0 as a function of (x1,x2) implementation=class=Contour name=y0 as a function of (x1,x2) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985], ...

# %% [markdown]
# ## Points défaillants / fiables

# %%
sampleSize = 1000
sampleInput = myDistribution.getSample(sampleSize)

e12 = sampleInput[: , 0:2]

Y = g3(e12)
Yarray = np.array(Y)
indices = Yarray > 0.0
indices = indices.ravel()
Xarray = np.array(e12)
XPositif = Xarray[indices, :]
autresIndices = [not indices[i] for i in range(len(indices))]
XNegatifs = Xarray[autresIndices, :]
myGraph = ot.Graph('Points défaillants / fiables', 'X1', 'X2', True, '')
myCloud = ot.Cloud(ot.Sample(XPositif), 'green', 'fsquare', '>0')
myGraph.add(myCloud)
myCloud = ot.Cloud(ot.Sample(XNegatifs), 'red', 'fsquare', '<0')
myGraph.add(myCloud)
myGraph.setLegendPosition("topright")
myGraph
# Out:
# class=Graph name=Points défaillants / fiables implementation=class=GraphImplementation name=Points défaillants / fiables title=Points défaillants / fiables xTitle=X1 yTitle=X2 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=>0 implementation=class=Cloud name=>0 derived from class=DrawableImplementation name=>0 legend=>0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=146 dimension=2 data=[[-2.18139,-0.43258],[1.43725,0.254775],[-2.29006,-1.46178],[1.78236,0.224354],[-1.78796,0.0926772],[1.96876,0.397189],[1.85579,-0.853559],[-1.53073,0.877138],[1.73821,-0.86813],[1.67297,-0.0197131],[1.70938,-0.150357],[-1.66086,-1.85139],[2.24623,1.21562],[-1.96869,0.249475],[2.11968,-0.735897],[-1.51696,-1.93819],[-3.09737,1.10496],[3.01263,0.0522118],[-1.5375,0.0207672],[-2.4067,1.36971],[1.86038,1.93123],[1.72546,0.407197],[-2.25867,-1.38558],[-1.78274,-0.616603],[-1.46295,1.08349],[-1.89234,0.236328],[1.49156,0.381884],[-1.45347,0.124891],[-1.55516,0.387491],[-1.51455,-0.22672],[2.05339,-0.870752],[-1.45717,0.139603],[1.4282,1.43364],[-1.73218,0.942989],[3.02799,-0.581715],[1.6948,-0.673015],[-1.64827,-1.71018],[-2.53986,0.466704],[-2.17211,0.6656],[-1.62506,-0.881944],[1.48031,0.501523],[1.89326,-0.61199],[-2.26608,0.27547],[-1.71131,0.550315],[1.94606,0.096919],[1.45919,0.542145],[1.45019,2.13718],[1.73945,-1.61696],[1.85337,-0.106422],[-2.20872,1.29287],[-1.73251,1.312],[1.57846,1.66825],[1.89005,-0.328276],[-2.19382,0.240077],[-1.49078,-1.59485],[1.7379,0.0946584],[1.70642,-2.01872],[1.43266,-1.33435],[-1.55666,-1.22215],[1.54237,0.285969],[1.58128,-0.162974],[2.09224,-0.153174],[-1.51577,-1.09214],[1.7657,-0.0789421],[1.57891,-0.267335],[2.15649,0.792492],[-2.13505,-1.05016],[1.6065,0.754646],[2.55533,-0.951745],[2.24097,2.26521],[-1.84225,0.226912],[-2.15135,-0.280828],[-2.72106,-1.97368],[-1.5599,-0.509307],[1.4814,-0.0601176],[1.57857,0.230513],[1.44503,-1.64284],[2.59603,0.325381],[-1.42826,0.171332],[-1.437,0.714616],[-2.10814,1.0115],[2.00363,0.242898],[-2.04317,-0.662876],[-1.44415,-1.04405],[1.43464,1.13337],[-2.18739,-1.40164],[1.57853,0.295833],[2.0749,-0.439438],[-2.66192,-0.412084],[1.89271,-0.255651],[-1.72668,0.473833],[1.58639,0.394006],[1.83936,0.951764],[-1.76574,1.91289],[-1.64198,1.48145],[-1.74047,-1.48568],[1.69044,-0.847893],[3.15958,-0.638041],[1.55867,2.49824],[-1.57912,2.47601],[1.49952,-1.31645],[-1.78119,-0.659973],[2.17952,1.20949],[-1.89151,-1.57614],[1.6379,-0.0259928],[-1.62657,-0.541059],[-1.78361,0.673807],[-1.42818,-0.875077],[1.79719,0.332588],[-2.98535,-0.0439368],[-1.87834,0.825403],[1.44456,0.64745],[-1.78039,0.045753],[-1.55986,-1.54194],[-1.79365,0.839747],[2.04098,0.429361],[1.92925,0.942426],[1.45293,-1.43499],[-1.68257,-1.22188],[2.69399,-0.707883],[1.76969,0.855202],[-1.52239,-0.023694],[-1.99535,-1.92335],[-1.63371,1.20223],[1.45173,0.0909237],[-1.95241,2.48445],[1.65237,1.62543],[1.43075,0.233584],[-1.58082,-0.637267],[2.0712,0.961381],[-1.53873,0.0136101],[-1.47884,1.2897],[2.31733,0.755502],[-1.7548,0.118944],[1.62925,-2.7466],[2.12309,0.920508],[-1.65891,0.100044],[1.91107,-0.112636],[-1.88328,-0.867955],[-1.57923,-1.15444],[-1.63959,-0.0436625],[-2.49198,-1.05122],[1.54502,0.477036],[2.36899,-0.308016],[1.68461,-1.662],[2.00508,-0.591989]] color=green fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1,class=Drawable name=<0 implementation=class=Cloud name=<0 derived from class=DrawableImplementation name=<0 legend=<0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=854 dimension=2 data=[[0.608202,0.182045],[-1.26617,0.466031],[-0.438266,-2.404],...,[-0.633479,0.259183],[-1.06159,-0.773031],[-0.973466,0.711512]] color=red fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1]

# %%
def linearSample(xmin, xmax, npoints):
    '''Returns a sample created from a regular grid
    from xmin to xmax with npoints points.'''
    step = (xmax-xmin)/(npoints-1)
    rg = ot.RegularGrid(xmin, step, npoints)
    vertices = rg.getVertices()
    return vertices

# %% [markdown]
# ## Surface d'état limite

# %%
lowerBound = ot.Point([X1.computeQuantile(alphaMin)[0], X2.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X1.computeQuantile(alphaMax)[0], X2.computeQuantile(alphaMax)[0]])
bounds = ot.Interval(lowerBound, upperBound)
nX = 100
nY = 100
boxExperiment = ot.Box([nX, nY], bounds)
#grille régulier 
inputSample = boxExperiment.generate()
outputSample = g3(inputSample)

# %%
# Create an empty graph
myGraph = ot.Graph('Limit state surface', 'X1', 'X2', True, '')
# Create the contour
levels = ot.Point([0.0])
labels = ["0.0"]
drawLabels = True
x = linearSample(lowerBound[0], upperBound[0], nX + 2)
y = linearSample(lowerBound[1], upperBound[1], nY + 2)
myContour = ot.Contour(x, y, outputSample, levels, labels, drawLabels)
myContour.setColor('black')
myGraph.add(myContour)

myGraph
# Out:
# class=Graph name=Limit state surface implementation=class=GraphImplementation name=Limit state surface title=Limit state surface xTitle=X1 yTitle=X2 axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Contour name=Unnamed x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[-2.32635],[-2.28028],[-2.23422],[-2.18815],[-2.14208],[-2.09602],[-2.04995],[-2.00388],[-1.95782],[-1.91175],[-1.86568],[-1.81962],[-1.77355],[-1.72749],[-1.68142],[-1.63535],[-1.58929],[-1.54322],[-1.49715],[-1.45109],[-1.40502],[-1.35896],[-1.31289],[-1.26682],[-1.22076],[-1.17469],[-1.12862],[-1.08256],[-1.03649],[-0.990425],[-0.944359],[-0.898293],[-0.852226],[-0.80616],[-0.760094],[-0.714028],[-0.667961],[-0.621895],[-0.575829],[-0.529762],[-0.483696],[-0.43763],[-0.391564],[-0.345497],[-0.299431],[-0.253365],[-0.207298],[-0.161232],[-0.115166],[-0.0690994],[-0.0230331],[0.0230331],[0.0690994],[0.115166],[0.161232],[0.207298],[0.253365],[0.299431],[0.345497],[0.391564],[0.43763],[0.483696],[0.529762],[0.575829],[0.621895],[0.667961],[0.714028],[0.760094],[0.80616],[0.852226],[0.898293],[0.944359],[0.990425],[1.03649],[1.08256],[1.12862],[1.17469],[1.22076],[1.26682],[1.31289],[1.35896],[1.40502],[1.45109],[1.49715],[1.54322],[1.58929],[1.63535],[1.68142],[1.72749],[1.77355],[1.81962],[1.86568],[1.91175],[1.95782],[2.00388],[2.04995],[2.09602],[2.14208],[2.18815],[2.23422],[2.28028],[2.32635]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[-2.32635],[-2.28028],[-2.23422],[-2.18815],[-2.14208],[-2.09602],[-2.04995],[-2.00388],[-1.95782],[-1.91175],[-1.86568],[-1.81962],[-1.77355],[-1.72749],[-1.68142],[-1.63535],[-1.58929],[-1.54322],[-1.49715],[-1.45109],[-1.40502],[-1.35896],[-1.31289],[-1.26682],[-1.22076],[-1.17469],[-1.12862],[-1.08256],[-1.03649],[-0.990425],[-0.944359],[-0.898293],[-0.852226],[-0.80616],[-0.760094],[-0.714028],[-0.667961],[-0.621895],[-0.575829],[-0.529762],[-0.483696],[-0.43763],[-0.391564],[-0.345497],[-0.299431],[-0.253365],[-0.207298],[-0.161232],[-0.115166],[-0.0690994],[-0.0230331],[0.0230331],[0.0690994],[0.115166],[0.161232],[0.207298],[0.253365],[0.299431],[0.345497],[0.391564],[0.43763],[0.483696],[0.529762],[0.575829],[0.621895],[0.667961],[0.714028],[0.760094],[0.80616],[0.852226],[0.898293],[0.944359],[0.990425],[1.03649],[1.08256],[1.12862],[1.17469],[1.22076],[1.26682],[1.31289],[1.35896],[1.40502],[1.45109],[1.49715],[1.54322],[1.58929],[1.63535],[1.68142],[1.72749],[1.77355],[1.81962],[1.86568],[1.91175],[1.95782],[2.00388],[2.04995],[2.09602],[2.14208],[2.18815],[2.23422],[2.28028],[2.32635]] levels=class=Point name=Unnamed dimension=1 values=[0] labels=[0.0] show labels=true derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10404 dimension=1 description=[y0] data=[[3.41189],[3.19968],[2.99172],...,[2.99172],[3.19968],[3.41189]] color=black fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %% [markdown]
# ## Les courbes iso-probables

# %%
alphaMin = 0.01
alphaMax = 1 - alphaMin
lowerBound = ot.Point([X1.computeQuantile(alphaMin)[0], X3.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X1.computeQuantile(alphaMax)[0], X3.computeQuantile(alphaMax)[0]])

# %%
nbPoints = [100, 100]
figure = g2.draw(lowerBound, upperBound, nbPoints)
figure.setTitle(" Les courbes iso-probables")
figure
# Out:
# class=Graph name=y0 as a function of (x1,x3) implementation=class=GraphImplementation name=y0 as a function of (x1,x3) title= Les courbes iso-probables xTitle=x1 yTitle=x3 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=y0 as a function of (x1,x3) implementation=class=Contour name=y0 as a function of (x1,x3) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985],[0.0704954],[0.117492],[0.164489],[0.211486],[0.258483],[0.30548],[0.352477],[0.399474],[0.446471],[0.493468],[0.540465],[0.587462],[0.634459],[0.681455],[0.728452],[0.775449],[0.822446],[0.869443],[0.91644],[0.963437],[1.01043],[1.05743],[1.10443],[1.15142],[1.19842],[1.24542],[1.29242],[1.33941],[1.38641],[1.43341],[1.4804],[1.5274],[1.5744],[1.62139],[1.66839],[1.71539],[1.76238],[1.80938],[1.85638],[1.90338],[1.95037],[1.99737],[2.04437],[2.09136],[2.13836],[2.18536],[2.23235],[2.27935],[2.32635]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985],[0.0704954],[0.117492],[0.164489],[0.211486],[0.258483],[0.30548],[0.352477],[0.399474],[0.446471],[0.493468],[0.540465],[0.587462],[0.634459],[0.681455],[0.728452],[0.775449],[0.822446],[0.869443],[0.91644],[0.963437],[1.01043],[1.05743],[1.10443],[1.15142],[1.19842],[1.24542],[1.29242],[1.33941],[1.38641],[1.43341],[1.4804],[1.5274],[1.5744],[1.62139],[1.66839],[1.71539],[1.76238],[1.80938],[1.85638],[1.90338],[1.95037],[1.99737],[2.04437],[2.09136],[2.13836],[2.18536],[2.23235],[2.27935],[2.32635]] levels=class=Point name=Unnamed dimension=1 values=[-2.34861] labels=[-2.34861] show labels=false derived from class=DrawableImplementation name=y0 as a function of (x1,x3) legend=-2.34861 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10000 dimension=1 description=[y0] data=[[4.17706],[4.02628],[3.87001],...,[3.87001],[4.02628],[4.17706]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=y0 as a function of (x1,x3) implementation=class=Contour name=y0 as a function of (x1,x3) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.02349 ...

# %% [markdown]
# ## Points défaillants / fiables

# %%
sampleSize = 1000
sampleInput = myDistribution.getSample(sampleSize)
Xa = np.array(sampleInput)
k = Xa[: , [0, 2]]

e13 = ot.Sample(k)
 

Y = g2(e13)
Yarray = np.array(Y)
indices = Yarray > 0.0
indices = indices.ravel()
Xarray = np.array(e13)
XPositif = Xarray[indices, :]
autresIndices = [not indices[i] for i in range(len(indices))]
XNegatifs = Xarray[autresIndices, :]
myGraph = ot.Graph('Points défaillants / fiables', 'X1', 'X3', True, '')
myCloud = ot.Cloud(ot.Sample(XPositif), 'green', 'fsquare', '>0')
myGraph.add(myCloud)
myCloud = ot.Cloud(ot.Sample(XNegatifs), 'red', 'fsquare', '<0')
myGraph.add(myCloud)
myGraph.setLegendPosition("topright")
myGraph
# Out:
# class=Graph name=Points défaillants / fiables implementation=class=GraphImplementation name=Points défaillants / fiables title=Points défaillants / fiables xTitle=X1 yTitle=X3 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=>0 implementation=class=Cloud name=>0 derived from class=DrawableImplementation name=>0 legend=>0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=186 dimension=2 data=[[-1.42375,0.282471],[1.14843,-1.04747],[1.74695,0.791825],[-1.91509,-1.29087],[-2.28791,0.677194],[-1.71615,-0.015619],[-2.43233,-0.829104],[-1.6186,0.513449],[1.62091,-0.504709],[-1.2124,0.992472],[-1.78245,-0.741824],[1.24863,-0.594013],[1.77109,1.49022],[-2.14926,0.880756],[1.17582,-1.84997],[-1.74827,-0.281673],[1.73389,-1.96591],[1.63877,-0.753824],[-2.72807,-1.93326],[1.8522,0.742602],[1.53036,-0.334363],[
28698,0.161114],[-1.2185,1.1732],[1.6514,-0.0622112],[-2.07219,1.14999],[2.48993,0.98295],[2.32593,-1.49835],[-2.07974,-0.831743],[-2.10155,0.754147],[-1.60822,1.39607],[1.69054,-0.774576],[1.63335,-0.240725],[-2.43612,-1.0783],[1.5866,1.9293],[-1.68851,0.581987],[1.93465,-2.55642],[-1.78819,0.217087],[-1.917,-1.65329],[1.79303,0.541054],[1.99417,-0.537323],[1.75684,-0.435832],[1.76561,-0.115292],[-1.6774,0.766096],[-2.1736,0.64015],[-1.69077,-0.550291],[-1.44718,0.651765],[1.68244,1.75996],[-2.24826,-0.385926],[1.87259,-1.21978],[-2.36999,-1.45064],[-1.95153,-1. ...

# %% [markdown]
# ## Surface d'état limite

# %%
lowerBound = ot.Point([X1.computeQuantile(alphaMin)[0], X3.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X1.computeQuantile(alphaMax)[0], X3.computeQuantile(alphaMax)[0]])
bounds = ot.Interval(lowerBound, upperBound)
nX = 100
nY = 100
boxExperiment = ot.Box([nX, nY], bounds)
#grille régulier 
inputSample = boxExperiment.generate()
outputSample = g2(inputSample)

# %%
# Create an empty graph
myGraph = ot.Graph('Limit state surface', 'X1', 'X3', True, '')
# Create the contour
levels = ot.Point([0.0])
labels = ["0.0"]
drawLabels = True
x = linearSample(lowerBound[0], upperBound[0], nX + 2)
y = linearSample(lowerBound[1], upperBound[1], nY + 2)
myContour = ot.Contour(x, y, outputSample, levels, labels, drawLabels)
myContour.setColor('black')
myGraph.add(myContour)

myGraph
# Out:
# class=Graph name=Limit state surface implementation=class=GraphImplementation name=Limit state surface title=Limit state surface xTitle=X1 yTitle=X3 axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Contour name=Unnamed x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[-2.32635],[-2.28028],[-2.23422],[-2.18815],[-2.14208],[-2.09602],[-2.04995],[-2.00388],[-1.95782],[-1.91175],[-1.86568],[-1.81962],[-1.77355],[-1.72749],[-1.68142],[-1.63535],[-1.58929],[-1.54322],[-1.49715],[-1.45109],[-1.40502],[-1.35896],[-1.31289],[-1.26682],[-1.22076],[-1.17469],[-1.12862],[-1.08256],[-1.03649],[-0.990425],[-0.944359],[-0.898293],[-0.852226],[-0.80616],[-0.760094],[-0.714028],[-0.667961],[-0.621895],[-0.575829],[-0.529762],[-0.483696],[-0.43763],[-0.391564],[-0.345497],[-0.299431],[-0.253365],[-0.207298],[-0.161232],[-0.115166],[-0.0690994],[-0.0230331],[0.0230331],[0.0690994],[0.115166],[0.161232],[0.207298],[0.253365],[0.299431],[0.345497],[0.391564],[0.43763],[0.483696],[0.529762],[0.575829],[0.621895],[0.667961],[0.714028],[0.760094],[0.80616],[0.852226],[0.898293],[0.944359],[0.990425],[1.03649],[1.08256],[1.12862],[1.17469],[1.22076],[1.26682],[1.31289],[1.35896],[1.40502],[1.45109],[1.49715],[1.54322],[1.58929],[1.63535],[1.68142],[1.72749],[1.77355],[1.81962],[1.86568],[1.91175],[1.95782],[2.00388],[2.04995],[2.09602],[2.14208],[2.18815],[2.23422],[2.28028],[2.32635]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[-2.32635],[-2.28028],[-2.23422],[-2.18815],[-2.14208],[-2.09602],[-2.04995],[-2.00388],[-1.95782],[-1.91175],[-1.86568],[-1.81962],[-1.77355],[-1.72749],[-1.68142],[-1.63535],[-1.58929],[-1.54322],[-1.49715],[-1.45109],[-1.40502],[-1.35896],[-1.31289],[-1.26682],[-1.22076],[-1.17469],[-1.12862],[-1.08256],[-1.03649],[-0.990425],[-0.944359],[-0.898293],[-0.852226],[-0.80616],[-0.760094],[-0.714028],[-0.667961],[-0.621895],[-0.575829],[-0.529762],[-0.483696],[-0.43763],[-0.391564],[-0.345497],[-0.299431],[-0.253365],[-0.207298],[-0.161232],[-0.115166],[-0.0690994],[-0.0230331],[0.0230331],[0.0690994],[0.115166],[0.161232],[0.207298],[0.253365],[0.299431],[0.345497],[0.391564],[0.43763],[0.483696],[0.529762],[0.575829],[0.621895],[0.667961],[0.714028],[0.760094],[0.80616],[0.852226],[0.898293],[0.944359],[0.990425],[1.03649],[1.08256],[1.12862],[1.17469],[1.22076],[1.26682],[1.31289],[1.35896],[1.40502],[1.45109],[1.49715],[1.54322],[1.58929],[1.63535],[1.68142],[1.72749],[1.77355],[1.81962],[1.86568],[1.91175],[1.95782],[2.00388],[2.04995],[2.09602],[2.14208],[2.18815],[2.23422],[2.28028],[2.32635]] levels=class=Point name=Unnamed dimension=1 values=[0] labels=[0.0] show labels=true derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10404 dimension=1 description=[y0] data=[[4.17706],[4.02932],[3.87631],...,[3.87631],[4.02932],[4.17706]] color=black fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %% [markdown]
# ## Les courbes iso-probables

# %%
alphaMin = 0.01
alphaMax = 1 - alphaMin
lowerBound = ot.Point([X2.computeQuantile(alphaMin)[0], X3.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X2.computeQuantile(alphaMax)[0], X3.computeQuantile(alphaMax)[0]])

# %%
nbPoints = [100, 100]
figure = g1.draw(lowerBound, upperBound, nbPoints)
figure.setTitle(" Les courbes iso-probables")
figure
# Out:
# class=Graph name=y0 as a function of (x2,x3) implementation=class=GraphImplementation name=y0 as a function of (x2,x3) title= Les courbes iso-probables xTitle=x2 yTitle=x3 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=y0 as a function of (x2,x3) implementation=class=Contour name=y0 as a function of (x2,x3) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985],[0.0704954],[0.117492],[0.164489],[0.211486],[0.258483],[0.30548],[0.352477],[0.399474],[0.446471],[0.493468],[0.540465],[0.587462],[0.634459],[0.681455],[0.728452],[0.775449],[0.822446],[0.869443],[0.91644],[0.963437],[1.01043],[1.05743],[1.10443],[1.15142],[1.19842],[1.24542],[1.29242],[1.33941],[1.38641],[1.43341],[1.4804],[1.5274],[1.5744],[1.62139],[1.66839],[1.71539],[1.76238],[1.80938],[1.85638],[1.90338],[1.95037],[1.99737],[2.04437],[2.09136],[2.13836],[2.18536],[2.23235],[2.27935],[2.32635]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.0234985],[0.0704954],[0.117492],[0.164489],[0.211486],[0.258483],[0.30548],[0.352477],[0.399474],[0.446471],[0.493468],[0.540465],[0.587462],[0.634459],[0.681455],[0.728452],[0.775449],[0.822446],[0.869443],[0.91644],[0.963437],[1.01043],[1.05743],[1.10443],[1.15142],[1.19842],[1.24542],[1.29242],[1.33941],[1.38641],[1.43341],[1.4804],[1.5274],[1.5744],[1.62139],[1.66839],[1.71539],[1.76238],[1.80938],[1.85638],[1.90338],[1.95037],[1.99737],[2.04437],[2.09136],[2.13836],[2.18536],[2.23235],[2.27935],[2.32635]] levels=class=Point name=Unnamed dimension=1 values=[-5.23852] labels=[-5.23852] show labels=false derived from class=DrawableImplementation name=y0 as a function of (x2,x3) legend=-5.23852 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10000 dimension=1 description=[y0] data=[[3.41189],[3.30256],[3.19323],...,[3.19323],[3.30256],[3.41189]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=y0 as a function of (x2,x3) implementation=class=Contour name=y0 as a function of (x2,x3) x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=1 data=[[-2.32635],[-2.27935],[-2.23235],[-2.18536],[-2.13836],[-2.09136],[-2.04437],[-1.99737],[-1.95037],[-1.90338],[-1.85638],[-1.80938],[-1.76238],[-1.71539],[-1.66839],[-1.62139],[-1.5744],[-1.5274],[-1.4804],[-1.43341],[-1.38641],[-1.33941],[-1.29242],[-1.24542],[-1.19842],[-1.15142],[-1.10443],[-1.05743],[-1.01043],[-0.963437],[-0.91644],[-0.869443],[-0.822446],[-0.775449],[-0.728452],[-0.681455],[-0.634459],[-0.587462],[-0.540465],[-0.493468],[-0.446471],[-0.399474],[-0.352477],[-0.30548],[-0.258483],[-0.211486],[-0.164489],[-0.117492],[-0.0704954],[-0.0234985],[0.02349 ...

# %% [markdown]
# ## Points défaillants / fiables

# %%
sampleSize = 1000
sampleInput = myDistribution.getSample(sampleSize)

e23 = sampleInput[: , 1:3]

Y = g1(e23)
Yarray = np.array(Y)
indices = Yarray > 0.0
indices = indices.ravel()
Xarray = np.array(e23)
XPositif = Xarray[indices, :]
autresIndices = [not indices[i] for i in range(len(indices))]
XNegatifs = Xarray[autresIndices, :]
myGraph = ot.Graph('Points défaillants / fiables', 'X2', 'X3', True, '')
myCloud = ot.Cloud(ot.Sample(XPositif), 'green', 'fsquare', '>0')
myGraph.add(myCloud)
myCloud = ot.Cloud(ot.Sample(XNegatifs), 'red', 'fsquare', '<0')
myGraph.add(myCloud)
myGraph.setLegendPosition("topright")
myGraph
# Out:
# class=Graph name=Points défaillants / fiables implementation=class=GraphImplementation name=Points défaillants / fiables title=Points défaillants / fiables xTitle=X2 yTitle=X3 axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=>0 implementation=class=Cloud name=>0 derived from class=DrawableImplementation name=>0 legend=>0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=33 dimension=2 data=[[2.56422,1.06801],[-1.19337,-2.00892],[1.42802,1.76692],[2.37086,1.18785],[-2.3627,-1.21456],[-1.82676,-2.44551],[-1.49095,-1.52865],[-3.04417,-1.53389],[1.72979,1.99576],[2.99396,1.24724],[1.37206,2.21408],[1.63088,1.27247],[1.40459,1.55157],[3.23297,0.679443],[-1.03298,-2.23695],[0.761486,2.82664],[1.26459,1.99937],[1.95871,1.94164],[-1.02425,-2.29266],[-2.66957,-2.68175],[1.84799,1.09677],[-1.69982,-1.32189],[-0.851743,-2.56997],[-1.88166,-1.92782],[1.98123,1.39639],[-1.61675,-1.63405],[1.47156,1.76534],[3.26278,1.53541],[2.4157,0.905239],[-1.16778,-2.19227],[-1.78,-1.32406],[1.88664,1.06235],[-1.70942,-1.29315]] color=green fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1,class=Drawable name=<0 implementation=class=Cloud name=<0 derived from class=DrawableImplementation name=<0 legend=<0 data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=967 dimension=2 data=[[1.44348,-1.06094],[0.350908,-0.879487],[0.316565,-0.469779],...,[2.38897,0.0328827],[-1.14918,-0.269547],[1.24856,-1.44037]] color=red fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1]

# %% [markdown]
# ## Surface d'état limite

# %%
lowerBound = ot.Point([X2.computeQuantile(alphaMin)[0], X3.computeQuantile(alphaMin)[0]])
upperBound = ot.Point([X2.computeQuantile(alphaMax)[0], X3.computeQuantile(alphaMax)[0]])
bounds = ot.Interval(lowerBound, upperBound)
nX = 100
nY = 100
boxExperiment = ot.Box([nX, nY], bounds)
#grille régulier 
inputSample = boxExperiment.generate()
outputSample = g1(inputSample)

# %%
# Create an empty graph
myGraph = ot.Graph('Limit state surface', 'X2', 'X3', True, '')
# Create the contour
levels = ot.Point([0.0])
labels = ["0.0"]
drawLabels = True
x = linearSample(lowerBound[0], upperBound[0], nX + 2)
y = linearSample(lowerBound[1], upperBound[1], nY + 2)
myContour = ot.Contour(x, y, outputSample, levels, labels, drawLabels)
myContour.setColor('black')
myGraph.add(myContour)

myGraph
# Out:
# class=Graph name=Limit state surface implementation=class=GraphImplementation name=Limit state surface title=Limit state surface xTitle=X2 yTitle=X3 axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Contour name=Unnamed x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[-2.32635],[-2.28028],[-2.23422],[-2.18815],[-2.14208],[-2.09602],[-2.04995],[-2.00388],[-1.95782],[-1.91175],[-1.86568],[-1.81962],[-1.77355],[-1.72749],[-1.68142],[-1.63535],[-1.58929],[-1.54322],[-1.49715],[-1.45109],[-1.40502],[-1.35896],[-1.31289],[-1.26682],[-1.22076],[-1.17469],[-1.12862],[-1.08256],[-1.03649],[-0.990425],[-0.944359],[-0.898293],[-0.852226],[-0.80616],[-0.760094],[-0.714028],[-0.667961],[-0.621895],[-0.575829],[-0.529762],[-0.483696],[-0.43763],[-0.391564],[-0.345497],[-0.299431],[-0.253365],[-0.207298],[-0.161232],[-0.115166],[-0.0690994],[-0.0230331],[0.0230331],[0.0690994],[0.115166],[0.161232],[0.207298],[0.253365],[0.299431],[0.345497],[0.391564],[0.43763],[0.483696],[0.529762],[0.575829],[0.621895],[0.667961],[0.714028],[0.760094],[0.80616],[0.852226],[0.898293],[0.944359],[0.990425],[1.03649],[1.08256],[1.12862],[1.17469],[1.22076],[1.26682],[1.31289],[1.35896],[1.40502],[1.45109],[1.49715],[1.54322],[1.58929],[1.63535],[1.68142],[1.72749],[1.77355],[1.81962],[1.86568],[1.91175],[1.95782],[2.00388],[2.04995],[2.09602],[2.14208],[2.18815],[2.23422],[2.28028],[2.32635]] y=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=102 dimension=1 description=[t] data=[[-2.32635],[-2.28028],[-2.23422],[-2.18815],[-2.14208],[-2.09602],[-2.04995],[-2.00388],[-1.95782],[-1.91175],[-1.86568],[-1.81962],[-1.77355],[-1.72749],[-1.68142],[-1.63535],[-1.58929],[-1.54322],[-1.49715],[-1.45109],[-1.40502],[-1.35896],[-1.31289],[-1.26682],[-1.22076],[-1.17469],[-1.12862],[-1.08256],[-1.03649],[-0.990425],[-0.944359],[-0.898293],[-0.852226],[-0.80616],[-0.760094],[-0.714028],[-0.667961],[-0.621895],[-0.575829],[-0.529762],[-0.483696],[-0.43763],[-0.391564],[-0.345497],[-0.299431],[-0.253365],[-0.207298],[-0.161232],[-0.115166],[-0.0690994],[-0.0230331],[0.0230331],[0.0690994],[0.115166],[0.161232],[0.207298],[0.253365],[0.299431],[0.345497],[0.391564],[0.43763],[0.483696],[0.529762],[0.575829],[0.621895],[0.667961],[0.714028],[0.760094],[0.80616],[0.852226],[0.898293],[0.944359],[0.990425],[1.03649],[1.08256],[1.12862],[1.17469],[1.22076],[1.26682],[1.31289],[1.35896],[1.40502],[1.45109],[1.49715],[1.54322],[1.58929],[1.63535],[1.68142],[1.72749],[1.77355],[1.81962],[1.86568],[1.91175],[1.95782],[2.00388],[2.04995],[2.09602],[2.14208],[2.18815],[2.23422],[2.28028],[2.32635]] levels=class=Point name=Unnamed dimension=1 values=[0] labels=[0.0] show labels=true derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10404 dimension=1 description=[y0] data=[[3.41189],[3.30473],[3.19756],...,[3.19756],[3.30473],[3.41189]] color=black fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]
